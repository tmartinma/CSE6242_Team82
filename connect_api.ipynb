# %%
import pandas as pd

# %%
centroids = pd.read_csv("taxi_zone_centroids.csv")

# Based on LocationID look for latitude and longtitude
zone = centroids[centroids["LocationID"] == 161].iloc[0]
lat, lon = zone["centroid_lat"], zone["centroid_lon"]

# Connect to OpenWeatherMap (example)
import requests
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=YOUR_KEY"
weather = requests.get(url).json()
